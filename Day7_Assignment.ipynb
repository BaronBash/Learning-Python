# %%
junior='jrn'
intermediate='Itm'
senior='snr'
Class= junior, intermediate, senior
print (Class)
# Out:
# ('jrn', 'Itm', 'snr')

# %%
import random
numbers=[]
counter=1
while counter <=5000:
    num=random.randint(1,2000)
    numbers.append(num)
    counter +=1
print (numbers)
# Out:
# [803, 1519, 1971, 497, 1954, 1669, 555, 1201, 1725, 326, 903, 1037, 321, 849, 1906, 1906, 472, 963, 760, 1535, 339, 740, 1975, 671, 1448, 457, 733, 1859, 1745, 1733, 1087, 503, 22, 1997, 1846, 981, 106, 1357, 54, 730, 1188, 535, 1852, 622, 915, 291, 798, 1759, 1044, 1997, 424, 1800, 1679, 437, 20, 1193, 922, 388, 1682, 587, 1485, 567, 1899, 769, 639, 1909, 594, 1653, 688, 1580, 484, 2000, 249, 1926, 1959, 1710, 1280, 1515, 810, 1875, 131, 1287, 887, 1534, 1524, 299, 148, 306, 135, 1355, 205, 822, 1587, 1618, 1072, 1361, 1049, 1313, 1803, 149, 1886, 937, 352, 393, 1995, 306, 58, 1876, 628, 805, 2, 1184, 1873, 1440, 581, 1832, 1531, 917, 10, 1117, 697, 1136, 886, 1146, 716, 1362, 1849, 5, 766, 1586, 474, 1694, 1847, 651, 972, 701, 982, 1825, 209, 505, 1863, 1397, 1064, 1959, 1632, 350, 1966, 1194, 1304, 1501, 1825, 1458, 1972, 1691, 1557, 634, 358, 470, 944, 395, 496, 543, 460, 1151, 1439, 216, 1037, 858, 639, 488, 1707, 1709, 1074, 357, 1840, 1856, 1297, 249, 1347, 1850, 1808, 153, 18
# ...

# %%
rl=random.choice(Class)
SN= list(map(lambda rl:f'{random.choice(Class)}{random.choice(numbers)}',numbers))
print(SN)
# Out:
# ['Itm279', 'snr382', 'jrn290', 'snr1324', 'Itm1637', 'snr967', 'Itm1146', 'snr1710', 'jrn1544', 'Itm1945', 'jrn549', 'Itm352', 'Itm971', 'snr1287', 'Itm198', 'snr1859', 'snr938', 'jrn289', 'snr31', 'snr404', 'snr445', 'jrn1160', 'Itm577', 'Itm626', 'Itm1184', 'snr405', 'jrn1533', 'jrn989', 'Itm737', 'jrn502', 'snr1920', 'snr243', 'snr1563', 'jrn1473', 'jrn1973', 'jrn1928', 'snr1409', 'jrn1824', 'jrn965', 'snr805', 'snr1827', 'Itm1963', 'Itm115', 'jrn1188', 'Itm674', 'snr1544', 'jrn1812', 'jrn372', 'Itm178', 'snr1287', 'snr1374', 'snr296', 'Itm1603', 'snr376', 'Itm1050', 'Itm1356', 'snr1115', 'Itm514', 'snr880', 'Itm1251', 'Itm1227', 'Itm432', 'snr1688', 'jrn1714', 'snr766', 'Itm1530', 'snr115', 'Itm1659', 'snr1540', 'snr1942', 'snr1869', 'snr517', 'snr1411', 'snr1273', 'snr62', 'snr1932', 'snr1927', 'Itm301', 'jrn616', 'snr306', 'snr1925', 'jrn777', 'Itm1883', 'jrn1298', 'jrn1591', 'Itm478', 'Itm461', 'Itm1066', 'Itm544', 'jrn1519', 'Itm1639', 'jrn1365', 'Itm429', 'Itm761', 'jrn540',
# ...

# %%
SN2=list(filter(lambda rl:rl.startswith('jrn'),sl)
print (SN2)
# Out:
#   File "<ipython-input-89-6bfbda344aa5>", line 2
#     print (SN2)
#     ^
# SyntaxError: invalid syntax

# %%
#Assignment day 1
print('my name is James')
# Out:
# my name is James

# %%
state='‘Im from a well-known village with good culture in kogi state'
print (state)
# Out:
# ‘Im from a well-known village with good culture in kogi state

# %%
totalmoney=1000
quantity=3
price= 450
print(f'i have {totalmoney} so i can buy {quantity} football at {price}')
# Out:
# i have 1000 so i can buy 3 football at 450

# %%
poem = """A nice day so ill go to the park.
and play on the slide and spider web.
immediately is 3PM i am going home."""
print(poem)
# Out:
# A nice day so ill go to the park.
# and play on the slide and spider web.
# immediately is 3PM i am going home.

# %% [markdown]
# # Assignment day 2

# %%
P = 5000
r = 6
t = 3

#calculate final amount after 3 years
ci =  P * (pow((1 + r / 100), t))
print (ci)
# Out:
# 5955.08

# %%
P = 550000
r = 5
t = 1
year1= P * (pow((1 + r / 100), t))
print (year1)

#year 1 intrest rate is 577500
year2p=577500+25000
year2p * (pow((1 + r / 100), t))
# Out:
# 577500.0
# 632625.0

# %%
#total amount for house after 3 years
P=632625
r=5
t=1
year3=P * (pow((1 + r / 100), t))
print (year3)

#The family needs 700000 to improve their house
#after 3 years the family has 664256.25
house_money = 700000-664256.25
print(house_money)
#They are short 35743.75
# Out:
# 664256.25
# 35743.75
